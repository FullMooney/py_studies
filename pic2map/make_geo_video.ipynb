# %%
import cv2
import numpy as np
import glob
 
img_array = []
                  
# for filename in glob.glob('trainA/*.jpg'):
for x in range(9):
    for i in range(4):
        for j in range(13):
            back_j = 12-j
            if i % 2 == 0:
                filename = 'trainA/A{}_{}_{}.jpg'.format(x, str(i).zfill(2), str(j).zfill(2))
            else:
                filename = 'trainA/A{}_{}_{}.jpg'.format(x, str(i).zfill(2), str(back_j).zfill(2))
            print(filename)
            img = cv2.imread(filename)
            height, width, layers = img.shape
            size = (width,height)
            img_array.append(img)
            img_array.append(img)
            img_array.append(img)
            img_array.append(img)
# Out:
# trainA/A0_00_00.jpg
# trainA/A0_00_01.jpg
# trainA/A0_00_02.jpg
# trainA/A0_00_03.jpg
# trainA/A0_00_04.jpg
# trainA/A0_00_05.jpg
# trainA/A0_00_06.jpg
# trainA/A0_00_07.jpg
# trainA/A0_00_08.jpg
# trainA/A0_00_09.jpg
# trainA/A0_00_10.jpg
# trainA/A0_00_11.jpg
# trainA/A0_00_12.jpg
# trainA/A0_01_12.jpg
# trainA/A0_01_11.jpg
# trainA/A0_01_10.jpg
# trainA/A0_01_09.jpg
# trainA/A0_01_08.jpg
# trainA/A0_01_07.jpg
# trainA/A0_01_06.jpg
# trainA/A0_01_05.jpg
# trainA/A0_01_04.jpg
# trainA/A0_01_03.jpg
# trainA/A0_01_02.jpg
# trainA/A0_01_01.jpg
# trainA/A0_01_00.jpg
# trainA/A0_02_00.jpg
# trainA/A0_02_01.jpg
# trainA/A0_02_02.jpg
# trainA/A0_02_03.jpg
# trainA/A0_02_04.jpg
# trainA/A0_02_05.jpg
# trainA/A0_02_06.jpg
# trainA/A0_02_07.jpg
# trainA/A0_02_08.jpg
# trainA/A0_02_09.jpg
# trainA/A0_02_10.jpg
# trainA/A0_02_11.jpg
# trainA/A0_02_12.jpg
# trainA/A0_03_12.jpg
# trainA/A0_03_11.jpg
# trainA/A0_03_10.jpg
# trainA/A0_03_09.jpg
# trainA/A0_03_08.jpg
# trainA/A0_03_07.jpg
# ...

# %%
out = cv2.VideoWriter('project.avi',cv2.VideoWriter_fourcc(*'DIVX'), 26, size) # filename, fourcc, fps, frameSize, isColor
 
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()
